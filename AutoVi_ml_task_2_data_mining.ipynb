# %% [markdown]
# <a href="https://colab.research.google.com/github/saipragna25/pragna255/blob/main/AutoVi_ml_task_2_data_mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install autoviml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 133 kB 35.6 MB/s
# ...
#      |████████████████████████████████| 76.8 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 268 kB 68.2 MB/s
# ...
#      |████████████████████████████████| 569 kB 59.3 MB/s
# ...
#      |████████████████████████████████| 240 kB 70.3 MB/s
# ...
#      |████████████████████████████████| 255.9 MB 45 kB/s
# ...
#      |████████████████████████████████| 125 kB 66.1 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 62.2 MB/s
# ...
#      |████████████████████████████████| 965 kB 52.7 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 58.0 MB/s
# ...
#      |████████████████████████████████| 120 kB 74.1 MB/s
# ...
#      |████████████████████████████████| 82 kB 1.1 MB/s
# ...
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234927 sha256=0ea4c988aa6a9e9873df309521bde1e84e823392e95c5ac9969a3aebedb7430b
# ...

# %%
from autoviml.Auto_ViML import Auto_ViML
# Out:
# Imported Auto_ViML version: 0.1.710. Call using:
#              m, feats, trainm, testm = Auto_ViML(train, target, test,
#                             sample_submission='',
#                             scoring_parameter='', KMeans_Featurizer=False,
#                             hyper_param='RS',feature_reduction=True,
#                              Boosting_Flag='CatBoost', Binning_Flag=False,
#                             Add_Poly=0, Stacking_Flag=False,Imbalanced_Flag=False,
#                             verbose=1)
#
#
# Imported Auto_NLP version: 0.1.01.. Call using:
#      train_nlp, test_nlp, nlp_pipeline, predictions = Auto_NLP(
#                 nlp_column, train, test, target, score_type='balanced_accuracy',
#                 modeltype='Classification',top_num_features=200, verbose=0,
#                 build_model=True)
# <style>.container { width:95% !important; }</style>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2938c21f-28cb-4670-a38d-159853c1e2ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2938c21f-28cb-4670-a38d-159853c1e2ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0 33.60
# 1              1       85             66             29        0 26.60
# 2              8      183             64              0        0 23.30
# 3              1       89             66             23       94 28.10
# 4              0      137             40             35      168 43.10
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180 32.90
# 764            2      122             70             27        0 36.80
# 765            5      121             72             23      112 26.20
# 766            1      126             60              0        0 30.10
# 767            1       93             70             31        0 30.40
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                        0.63   50        1
# ...

# %%
num = int(0.9*df.shape[0])
train = df[:num]
print(train.shape)
test = df[num:]
print(test.shape)
# Out:
# (691, 9)
# (77, 9)

# %%
target = 'Outcome'
sample_submission=''
scoring_parameter = 'balanced-accuracy'

# %%
m, feats, trainm, testm = Auto_ViML(train, target, test, sample_submission,
                                    scoring_parameter=scoring_parameter,
                                    hyper_param='GS',feature_reduction=True,
                                     Boosting_Flag=True,Binning_Flag=False,
                                    Add_Poly=0, Stacking_Flag=False,                                    
                                    Imbalanced_Flag=False, 
                                    verbose=1)
# Out:
# ##############  D A T A   S E T  A N A L Y S I S  #######################
# Training Set Shape = (691, 9)
#     Training Set Memory Usage = 0.05 MB
# Test Set Shape = (77, 9)
#     Test Set Memory Usage = 0.01 MB
# Single_Label Target: ['Outcome']
#
# ################ Binary_Classification VISUALIZATION Started #####################
# Random shuffling the data set before training
#     Using GridSearchCV for Hyper Parameter Tuning. This is slow. Switch to RS for faster tuning...
#        Class  -> Counts -> Percent
#            0:     454  ->   65.7%
#            1:     237  ->   34.3%
#     Target Outcome is already numeric. No transformation done.
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# ...
